# %%
import tensorflow as tf
import tensorflow_datasets

# %%
(train,test),info=tensorflow_datasets.load('mnist',split=['train','test'],as_supervised=True,with_info=True)

# %%
train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(28, 28, 1), dtype=tf.uint8, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>

# %%
def normalize(image,label):
    return tf.cast(image,tf.float32)/256,label
train=train.map(normalize)
train
# Out:
# <_MapDataset element_spec=(TensorSpec(shape=(28, 28, 1), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>

# %%
train=train.cache()

# %%
info.splits['train']
# Out:
# <SplitInfo num_examples=60000, num_shards=1>

# %%
train=train.shuffle(info.splits['train'].num_examples)

# %%
train=train.batch(256)

# %%
train=train.prefetch(tf.data.experimental.AUTOTUNE)

# %%
train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 28, 28, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %%
test=test.map(normalize)

# %%
test=test.batch(256)

# %%
test=test.cache()
test=test.prefetch(tf.data.experimental.AUTOTUNE)

# %%
model=tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')

])
# Out:
# C:\Users\LOQ\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(0.001),loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

# %%
model.fit(train,epochs=10,validation_data=test)
# Out:
# Epoch 1/10
# C:\Users\LOQ\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\nn.py:717: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.4475 - sparse_categorical_accuracy: 0.8776 - val_loss: 0.2283 - val_sparse_categorical_accuracy: 0.9342
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1999 - sparse_categorical_accuracy: 0.9443 - val_loss: 0.1707 - val_sparse_categorical_accuracy: 0.9499
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1483 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.1353 - val_sparse_categorical_accuracy: 0.9598
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1180 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.1151 - val_sparse_categorical_accuracy: 0.9653
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0967 - sparse_categorical_accuracy: 0.9726 - val_loss: 0.0992 - val_sparse_categorical_accuracy: 0.9709
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0816 - sparse_categorical_accuracy: 0.9768 - val_loss: 0.0920 - val_sparse_categorical_accuracy: 0.9720
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0707 - sparse_categorical_accuracy: 0.9797 - val_loss: 0.0863 - val_sparse_categorical_accuracy: 0.9737
# Epoch 8/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0610 - sparse_categorical_accuracy: 0.9828 - val_loss: 0.0831 - val_sparse_categorical_accuracy: 0.9753
# Epoch 9/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0537 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.0821 - val_sparse_categorical_accuracy: 0.9756
# Epoch 10/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0478 - sparse_categorical_accuracy: 0.9867 - val_loss: 0.0761 - val_sparse_categorical_accuracy: 0.9764
