# %%
import requests
import html

# %%
page=requests.get('https://ganjoor.net/khayyam/robaee/sh20')

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html lang="fa-IR" dir="rtl">\r\n<head>\r\n    <meta charset="utf-8">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1">\r\n    <title>\r\n        \xda\xaf\xd9\x86\xd8\xac\xd9\x88\xd8\xb1 \xc2\xbb \xd8\xae\xdb\x8c\xd8\xa7\xd9\x85 \xc2\xbb \xd8\xb1\xd8\xa8\xd8\xa7\xd8\xb9\xdb\x8c\xd8\xa7\xd8\xaa \xc2\xbb \xd8\xb1\xd8\xa8\xd8\xa7\xd8\xb9\xdb\x8c \xd8\xb4\xd9\x85\xd8\xa7\xd8\xb1\xd9\x87\xd9\x94 \xdb\xb2\xdb\xb0\r\n    </title>\r\n    <link href="https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap" rel="stylesheet">\r\n    <link href="/css/p8.css?version=83" rel="stylesheet" type="text/css">\r\n    <link rel="shortcut icon" href="/favicon.ico?version=1" type="image/x-icon">\r\n    <link rel="search" type="application/opensearchdescription+xml" title="\xda\xaf\xd9\x86\xd8\xac\xd9\x88\xd8\xb1" href="https://ganjoor.net/search.xml">\r\n    <script src="/lib/jquery/dist/jquery.min.js"></script>\r\n    <script src=
# ...

# %%
from lxml import html
tree = html.fromstring(page.content)

# %%
tree
# Out:
# <Element html at 0x24cba76f610>

# %%
tree.xpath('//div[@class="b"]/div/p/text()')
# Out:
# ['پیش از من و تو لیل و نهاری بوده\u200cست',
#  'گردنده فلک نیز به کاری بوده است',
#  'هر جا که قدم نهی تو بر روی زمین',
#  'آن مردمک چشم نگاری بوده\u200cست']

# %%
for i in range(1,178):
    page=requests.get('https://ganjoor.net/khayyam/robaee/sh'+ str(i)+'/')
    tree = html.fromstring(page.content)
    with open('khayyam.txt','a',encoding='utf-8') as f:
        for t in tree.xpath('//div[@class="b"]/div/p/text()'):
            f.write('|'+str(t.replace('\u200c',' '))+'\n')

# %%
page = requests.get('https://ganjoor.net/moulavi/masnavi/daftar2/sh12/')
tree = html.fromstring(page.content)

with open('khayyam.txt', 'w', encoding='utf-8') as f:
    for t in tree.xpath('//div[@class="b"]/div/p/text()'):
        f.write('|' + str(t.replace('\u200c', ' ')) + '\n')
