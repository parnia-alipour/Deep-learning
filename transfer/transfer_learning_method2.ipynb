# %%
from pyexpat import features
import  os
from keras.src.utils.module_utils import tensorflow
os.path.expanduser('~/.keras/models')
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout,Flatten
import pickle
from tensorflow.keras.applications.vgg16 import VGG16
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
model_cvv=VGG16(weights="imagenet",input_shape=(150,150,3), include_top=False)

# %%
model_cvv.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_13 (InputLayer)     │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 150, 150, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 150, 150, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 75, 75, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 75, 75, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 75, 75, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 37, 37, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 37, 37, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 37, 37, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 37, 37, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 18, 18, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 18, 18, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 18, 18, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 18, 18, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 9, 9, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 9, 9, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 9, 9, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 9, 9, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 4, 4, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
data_generatorr=ImageDataGenerator(rescale=1.0/255,)
generate=data_generatorr.flow_from_directory('train_transform/',target_size=(150,150),class_mode='binary',batch_size=20)
# Out:
# Found 2000 images belonging to 2 classes.

# %%
data_generatorr_test = ImageDataGenerator(rescale=1.0 / 255, )
generate_test = data_generatorr_test.flow_from_directory('test_transform/', target_size=(150, 150), class_mode='binary',batch_size=10)
# Out:
# Found 1400 images belonging to 2 classes.

# %%
model_cvv.trainable = False

# %%
model=Sequential()
model.add(model_cvv)
model.add(Flatten())
model.add(Dense(256,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 4, 4, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 256)            │     2,097,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,812,353 (64.13 MB)
#  Trainable params: 2,097,665 (8.00 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
model.fit(generate,steps_per_epoch=100,epochs=30,validation_data=generate_test,validation_steps=30)
# Out:
# Epoch 1/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 42s 417ms/step - accuracy: 0.8120 - loss: 0.4296 - val_accuracy: 0.8667 - val_loss: 0.3451
# Epoch 2/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 46s 465ms/step - accuracy: 0.8960 - loss: 0.2580 - val_accuracy: 0.8733 - val_loss: 0.2964
# Epoch 3/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 49s 495ms/step - accuracy: 0.9110 - loss: 0.2094 - val_accuracy: 0.8800 - val_loss: 0.2433
# Epoch 4/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 50s 496ms/step - accuracy: 0.9390 - loss: 0.1530 - val_accuracy: 0.9100 - val_loss: 0.2302
# Epoch 5/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 50s 497ms/step - accuracy: 0.9475 - loss: 0.1269 - val_accuracy: 0.9067 - val_loss: 0.2442
# Epoch 6/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 49s 495ms/step - accuracy: 0.9610 - loss: 0.0960 - val_accuracy: 0.8933 - val_loss: 0.2487
# Epoch 7/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 57s 573ms/step - accuracy: 0.9645 - loss: 0.0972 - val_accuracy: 0.9133 - val_loss: 0.2184
# Epoch 8/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 50s 506ms/step - accuracy: 0.9815 - loss: 0.0601 - val_accuracy: 0.9267 - val_loss: 0.2030
# Epoch 9/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 50s 497ms/step - accuracy: 0.9835 - loss: 0.0579 - val_accuracy: 0.8900 - val_loss: 0.3475
# Epoch 10/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 50s 497ms/step - accuracy: 0.9850 - loss: 0.0444 - val_accuracy: 0.8733 - val_loss: 0.3376
# Epoch 11/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 49s 493ms/step - accuracy: 0.9835 - loss: 0.0414 - val_accuracy: 0.9000 - val_loss: 0.2581
# Epoch 12/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 48s 483ms/step - accuracy: 0.9845 - loss: 0.0480 - val_accuracy: 0.8833 - val_loss: 0.3279
# Epoch 13/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 49s 492ms/step - accuracy: 0.9900 - loss: 0.0279 - val_accuracy: 0.8967 - val_loss: 0.2953
# Epoch 14/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 60s 605ms/step - accuracy: 0.9920 - loss: 0.0265 - val_accuracy: 0.9133 - val_loss: 0.2391
# Epoch 15/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 49s 487ms/step - accuracy: 0.9845 - loss: 0.0382 - val_accuracy: 0.8733 - val_loss: 0.4213
# Epoch 16/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 48s 481ms/step - accuracy: 0.9860 - loss: 0.0338 - val_accuracy: 0.8933 - val_loss: 0.3709
# Epoch 17/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 48s 480ms/step - accuracy: 0.9895 - loss: 0.0310 - val_accuracy: 0.9033 - val_loss: 0.3337
# Epoch 18/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 48s 481ms/step - accuracy: 0.9955 - loss: 0.0197 - val_accuracy: 0.8933 - val_loss: 0.4575
# Epoch 19/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 50s 503ms/step - accuracy: 0.9945 - loss: 0.0200 - val_accuracy: 0.8833 - val_loss: 0.3967
# Epoch 20/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 50s 496ms/step - accuracy: 0.9925 - loss: 0.0235 - val_accuracy: 0.8633 - val_loss: 0.6751
# Epoch 21/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 50s 501ms/step - accuracy: 0.9865 - loss: 0.0302 - val_accuracy: 0.8900 - val_loss: 0.4168
# Epoch 22/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 50s 502ms/step - accuracy: 0.9940 - loss: 0.0216 - val_accuracy: 0.8867 - val_loss: 0.4243
# Epoch 23/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 197s 2s/step - accuracy: 0.9900 - loss: 0.0259 - val_accuracy: 0.8933 - val_loss: 0.3623
# Epoch 24/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 78s 762ms/step - accuracy: 0.9935 - loss: 0.0200 - val_accuracy: 0.8800 - val_loss: 0.4783
# Epoch 25/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 61s 613ms/step - accuracy: 0.9920 - loss: 0.0208 - val_accuracy: 0.8600 - val_loss: 0.4991
# Epoch 26/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 50s 499ms/step - accuracy: 0.9870 - loss: 0.0327 - val_accuracy: 0.8600 - val_loss: 0.5416
# Epoch 27/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 49s 494ms/step - accuracy: 0.9785 - loss: 0.0573 - val_accuracy: 0.9000 - val_loss: 0.3318
# Epoch 28/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 76s 763ms/step - accuracy: 0.9905 - loss: 0.0297 - val_accuracy: 0.9100 - val_loss: 0.2888
# Epoch 29/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 46s 463ms/step - accuracy: 0.9905 - loss: 0.0308 - val_accuracy: 0.9033 - val_loss: 0.3884
# Epoch 30/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 49s 487ms/step - accuracy: 0.9945 - loss: 0.0166 - val_accuracy: 0.9033 - val_loss: 0.3528
